# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewEPrince/codespaces-blank/blob/main/BallsNetv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Installs
# !pip install tensorflow --upgrade
# !pip install tensorflow-gpu --upgrade
# !pip install keras --upgrade

# %%
#@title Imports
import json
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import joblib
from google.colab import files


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report

import tensorflow as tf
print(tf.__version__)
from keras import regularizers
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout, Masking, BatchNormalization, GlobalAveragePooling2D
from keras.optimizers import Adam, SGD, RMSprop, AdamW, Adadelta, Adagrad, Adamax, Nadam
from keras.losses import SparseCategoricalCrossentropy
from keras.metrics import Accuracy, Precision, Recall, F1Score, AUC, CategoricalAccuracy, SparseCategoricalAccuracy
from keras.utils import to_categorical
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping, Callback, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
# Out:
# 2.15.0

# %%
#@title Get Season Data
season_urls = {
    "season_17_urls" : {
    "https://ballchasing.com/api/groups/1premier-fljs2rxwse/" : 1,
    "https://ballchasing.com/api/groups/2master-er4ijj6bzr/" : 2,
    "https://ballchasing.com/api/groups/3elite-s8z53z7uh5/" : 3,
    "https://ballchasing.com/api/groups/4veteran-02ujkewot4/" : 4,
    "https://ballchasing.com/api/groups/5rival-mrp8b1bamo/" : 5,
    "https://ballchasing.com/api/groups/6challenger-a3a3j0nkec/" : 6,
    "https://ballchasing.com/api/groups/7prospect-jt1f5epq9r/" : 7,
    "https://ballchasing.com/api/groups/8contender-9n998x8mm8/" : 8,
    "https://ballchasing.com/api/groups/9amateur-wmq7szund6/" : 9
    }
    ,
    "season_18_urls" : {
    "https://ballchasing.com/api/groups/1premier-0bltbgd7ox/" : 1,
    "https://ballchasing.com/api/groups/2master-oe6pooca8v/" : 2,
    "https://ballchasing.com/api/groups/3elite-n4j3g5puuo/" : 3,
    "https://ballchasing.com/api/groups/4veteran-ntqifly5e6/" : 4,
    "https://ballchasing.com/api/groups/5rival-07eg1qhi9a/" : 5,
    "https://ballchasing.com/api/groups/6challenger-57i0g8cxr5/" : 6,
    "https://ballchasing.com/api/groups/7prospect-qyyo3i7lvm/" : 7,
    "https://ballchasing.com/api/groups/8contender-gjm3xw4bb5/" : 8,
    "https://ballchasing.com/api/groups/9amateur-zmcevpgmnn/" : 9
  }
}

headers = {'Authorization': '8wjl1G9d8V8Ymfju7hH8K57aKNUiNhYe5oOYOxNr'}

for s, season in enumerate(season_urls.keys()):
  for u, url in enumerate(season_urls[season].keys()):
    response = requests.get(url, headers=headers)
    data = json.loads(response.text)
    temp_df = pd.json_normalize(data)
    temp_df['rank'] = season_urls[season][url]
    df = temp_df if s == 0 and u == 0 else pd.concat([df, temp_df])

# display(df)

# %%
#@title Extract Player Data
for i in range(len(df)):
  rank_df = pd.DataFrame(pd.json_normalize(df.iloc[i]['players']))
  for j in range(len(rank_df)):
    temp_df = pd.DataFrame(rank_df.iloc[j]).T
    temp_df['rank'] = df.iloc[i]['rank']
    player_df = temp_df if i == 0 and j == 0 else pd.concat([player_df, temp_df])

display(player_df)
# Out:
#    platform                                id               name  \
# 0     Steam                 76561198968803489              .Andy
# 1     Steam                 76561198174404581             ASHES.
# 2     Steam                 76561198065191659  Almost Magic Mike
# 3     Steam                 76561198183908069            Angebro
# 4      Epic  766976eafb6a412d9327382ad43e4fb6          Anges Dad
# ..      ...                               ...                ...
# 54      PS4                          jdoyle15           jdoyle15
# 55     Epic  a0260508a58545a285792aca8a0188c0     llToxic_Dripll
# 56    Steam                 76561198120315116         lostperson
# 57    Steam                 76561198148415662                ous
# 58     XBox                   youngslingblade    youngslingblade
#
#             team cumulative.games cumulative.wins cumulative.win_percentage  \
# 0     HURRICANES               52              28                 53.846153
# 1     HURRICANES               54              24                 44.444443
# 2     HURRICANES               36              14                  38.88889
# 3     HURRICANES               37              15                  40.54054
# 4     HURRICANES                4               4                     100.0
# ..           ...              ...             ...                       ...
# 54  HOUSE SALADS               11               6                 54.545456
# 55  SKETCH SQUAD               32              12                      37.5
# 56   PRAETORIANS               52              20                  38.46154
# 57  ALFREDO ARMY               47              19                 40.425533
# 58  HOUSE SALADS                2               2                     100.0
#
#    cumulative.play_duration cumulative.core.shots  \
# 0                     18599                   163
# 1                     20318                   132
# 2                     12751                    81
# 3                     13912                   101
# 4                      1367                    12
# ..                      ...                   ...
# 54                     3871                     9
# 55                    12147                    69
# 56                    18760                    99
# 57                    16958                    89
# 58                      702                     3
#
#    cumulative.core.shots_against  ...  \
# 0                            435  ...
# 1                            458  ...
# 2                            299  ...
# 3                            289  ...
# 4                             27  ...
# ..                           ...  ...
# 54                            76  ...
# 55                           237  ...
# 56                           390  ...
# 57                           309  ...
# 58                            16  ...
#
#    game_average.positioning.percent_defensive_third  \
# 0                                          49.01793
# 1                                          46.23599
# 2                                          47.43638
# 3                                         45.235226
# 4                                         47.895966
# ..                                              ...
# 54                                        58.638527
# 55                                        50.090034
# 56                                        52.532864
# 57                                        51.387386
# 58                                         68.34377
#
#    game_average.positioning.percent_offensive_third  \
# 0                                         20.097721
# 1                                          22.74716
# 2                                         21.085146
# 3                                         21.447758
# 4                                         19.881123
# ..                                              ...
# 54                                        16.573832
# 55                                        21.179878
# 56                                        17.898989
# 57                                        18.737587
# 58                                        12.510871
#
#    game_average.positioning.percent_neutral_third  \
# 0                                       30.884348
# 1                                       31.016848
# 2                                        31.47848
# 3                                       33.317013
# 4                                        32.22291
# ..                                            ...
# 54                                      24.787643
# 55                                      28.730082
# 56                                      29.568146
# 57                                      29.875029
# 58                                      19.145359
#
#    game_average.positioning.percent_defensive_half  \
# 0                                         65.05415
# 1                                         62.92222
# 2                                        64.156166
# 3                                        62.104992
# 4                                        65.688576
# ..                                             ...
# 54                                        72.55447
# 55                                       65.502304
# 56                                        68.87725
# 57                                        67.51461
# 58                                        79.77764
#
#    game_average.positioning.percent_offensive_half  \
# 0                                        34.945843
# 1                                        37.077785
# 2                                         35.84383
# 3                                         37.89501
# 4                                         34.31142
# ..                                             ...
# 54                                        27.44554
# 55                                       34.497692
# 56                                       31.122753
# 57                                       32.485394
# 58                                       20.222357
#
#    game_average.positioning.percent_behind_ball  \
# 0                                     72.205505
# 1                                      69.55603
# 2                                      71.22679
# 3                                      70.86109
# 4                                      75.70233
# ..                                          ...
# 54                                     72.22322
# 55                                      69.2537
# 56                                     73.60178
# 57                                     72.28132
# 58                                    78.017914
#
#    game_average.positioning.percent_infront_ball game_average.demo.inflicted  \
# 0                                      27.794495                    0.846154
# 1                                      30.443964                    1.444444
# 2                                      28.773212                    1.944444
# 3                                      29.138906                    0.675676
# 4                                       24.29767                        0.75
# ..                                           ...                         ...
# 54                                     27.776785                         1.0
# 55                                       30.7463                     0.46875
# 56                                     26.398214                    0.826923
# 57                                      27.71868                         1.0
# 58                                     21.982082                         0.0
#
#    game_average.demo.taken rank
# 0                 1.076923    1
# 1                 1.074074    1
# 2                     1.25    1
# 3                 0.891892    1
# 4                      1.0    1
# ..                     ...  ...
# 54                0.636364    9
# 55                 0.46875    9
# 56                0.711538    9
# 57                0.914894    9
# 58                     1.5    9
#
# [2027 rows x 167 columns]

# %%
#@title Initialize Data for Training
temp_player_df = player_df.drop(columns=['platform'], axis=1)
temp_player_df = temp_player_df.drop(columns=['id'], axis=1)
temp_player_df = temp_player_df.drop(columns=['name'], axis=1)
temp_player_df = temp_player_df.drop(columns=['team'], axis=1)

temp_player_df = temp_player_df.drop(columns=['cumulative.games'], axis=1)
# temp_player_df = temp_player_df.filter(like='percent')
# X = np.asarray(temp_player_df)
X = np.asarray(temp_player_df.drop(columns=['rank'], axis=1))
y = np.asarray(player_df['rank'])

temp_player_df.head()
print(X.shape)
print(X[0][-1])
# Out:
# (2027, 161)
# 1.0769231

# %%
# Step 1: Split the data into training and testing sets
print(y)
y_minus_one = np.asarray([val - 1 for val in y])
print(y_minus_one)
X_train, X_test, y_train, y_test = train_test_split(X, y_minus_one, test_size=0.2, random_state=42)

# Step 2: Normalize the input data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Save the scaler using joblib
joblib.dump(scaler, "ballsnet_scaler.joblib")

y_train = y_train.astype('int8')
y_test = y_test.astype('int8')

# Ensure labels are starting from 0 and encoded correctly
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_train_encoded = y_train_encoded.reshape(-1,)

y_test_encoded = label_encoder.transform(y_test)

y_train_categorical = to_categorical(y_train_encoded)
y_test_categorical = to_categorical(y_test_encoded)

print(X_train_scaled.shape, X_test_scaled.shape, y_train_categorical.shape)
# Out:
# [1 1 1 ... 9 9 9]
# [0 0 0 ... 8 8 8]
# (1621, 161) (406, 161) (1621, 9)

# %%
# Model Definition
input_dim = X_train_scaled.shape[1]

model = Sequential()
model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01), kernel_initializer='he_normal', input_dim=input_dim))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01), kernel_initializer='he_normal'))
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01), kernel_initializer='he_normal'))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01), kernel_initializer='he_normal'))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01), kernel_initializer='he_normal'))
model.add(Dense(9, activation='softmax'))

model.summary()

# Model Compilation
optimizer = Adam(learning_rate=0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=[CategoricalAccuracy()])

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)
callbacks = [early_stopping, reduce_lr]

# Model Training
history = model.fit(
    X_train_scaled.astype('float16'),
    y_train_categorical,
    epochs=200,
    batch_size=32,
    verbose=1,
    shuffle=True,
    callbacks=callbacks,
    validation_data=(X_test_scaled.astype('float16'), y_test_categorical)
)

# Model Evaluation
loss, categorical_accuracy = model.evaluate(X_test_scaled.astype('float16'), y_test_categorical)
print(f"Test Accuracy: {categorical_accuracy * 100}")

# Save the entire model to a HDF5 file
model.save("ballsnet1.2.h5")
files.download("ballsnet1.2.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:73: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_90"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Layer (type)                       ┃ Output Shape                  ┃     Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ dense_462 (Dense)                  │ (None, 256)                   │      41,472 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ batch_normalization_101            │ (None, 256)                   │       1,024 │
# │ (BatchNormalization)               │                               │             │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dropout_98 (Dropout)               │ (None, 256)                   │           0 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense_463 (Dense)                  │ (None, 128)                   │      32,896 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense_464 (Dense)                  │ (None, 128)                   │      16,512 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense_465 (Dense)                  │ (None, 64)                    │       8,256 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense_466 (Dense)                  │ (None, 64)                    │       4,160 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense_467 (Dense)                  │ (None, 9)                     │         585 │
# └────────────────────────────────────┴───────────────────────────────┴─────────────┘
#  Total params: 104,905 (409.79 KB)
#  Trainable params: 104,393 (407.79 KB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - categorical_accuracy: 0.1758 - loss: 14.7980 - val_categorical_accuracy: 0.2192 - val_loss: 13.0444 - learning_rate: 0.0010
# Epoch 2/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.2476 - loss: 12.5251 - val_categorical_accuracy: 0.2611 - val_loss: 11.1809 - learning_rate: 0.0010
# Epoch 3/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.3284 - loss: 10.6517 - val_categorical_accuracy: 0.3818 - val_loss: 9.4836 - learning_rate: 0.0010
# Epoch 4/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.3692 - loss: 9.0766 - val_categorical_accuracy: 0.3793 - val_loss: 8.1002 - learning_rate: 0.0010
# Epoch 5/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4127 - loss: 7.7255 - val_categorical_accuracy: 0.4187 - val_loss: 6.8970 - learning_rate: 0.0010
# Epoch 6/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4357 - loss: 6.5962 - val_categorical_accuracy: 0.3916 - val_loss: 5.9695 - learning_rate: 0.0010
# Epoch 7/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4123 - loss: 5.7387 - val_categorical_accuracy: 0.4310 - val_loss: 5.1770 - learning_rate: 0.0010
# Epoch 8/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4493 - loss: 4.9454 - val_categorical_accuracy: 0.4433 - val_loss: 4.5448 - learning_rate: 0.0010
# Epoch 9/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4462 - loss: 4.4060 - val_categorical_accuracy: 0.4409 - val_loss: 4.0493 - learning_rate: 0.0010
# Epoch 10/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4554 - loss: 3.9147 - val_categorical_accuracy: 0.4433 - val_loss: 3.5978 - learning_rate: 0.0010
# Epoch 11/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4617 - loss: 3.4998 - val_categorical_accuracy: 0.4532 - val_loss: 3.2766 - learning_rate: 0.0010
# Epoch 12/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4720 - loss: 3.1953 - val_categorical_accuracy: 0.4138 - val_loss: 3.0300 - learning_rate: 0.0010
# Epoch 13/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4628 - loss: 2.9589 - val_categorical_accuracy: 0.4187 - val_loss: 2.7847 - learning_rate: 0.0010
# Epoch 14/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4607 - loss: 2.6906 - val_categorical_accuracy: 0.4261 - val_loss: 2.6045 - learning_rate: 0.0010
# Epoch 15/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4754 - loss: 2.5247 - val_categorical_accuracy: 0.4483 - val_loss: 2.4350 - learning_rate: 0.0010
# Epoch 16/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4807 - loss: 2.3928 - val_categorical_accuracy: 0.4384 - val_loss: 2.2952 - learning_rate: 0.0010
# Epoch 17/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5021 - loss: 2.2065 - val_categorical_accuracy: 0.3842 - val_loss: 2.2428 - learning_rate: 0.0010
# Epoch 18/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4750 - loss: 2.1391 - val_categorical_accuracy: 0.4089 - val_loss: 2.1333 - learning_rate: 0.0010
# Epoch 19/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4774 - loss: 2.0931 - val_categorical_accuracy: 0.4335 - val_loss: 2.0513 - learning_rate: 0.0010
# Epoch 20/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4524 - loss: 2.0463 - val_categorical_accuracy: 0.4384 - val_loss: 1.9920 - learning_rate: 0.0010
# Epoch 21/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4741 - loss: 1.9419 - val_categorical_accuracy: 0.4113 - val_loss: 1.9572 - learning_rate: 0.0010
# Epoch 22/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4726 - loss: 1.8990 - val_categorical_accuracy: 0.3892 - val_loss: 1.9418 - learning_rate: 0.0010
# Epoch 23/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4548 - loss: 1.8917 - val_categorical_accuracy: 0.4286 - val_loss: 1.8847 - learning_rate: 0.0010
# Epoch 24/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4588 - loss: 1.8637 - val_categorical_accuracy: 0.4039 - val_loss: 1.8221 - learning_rate: 0.0010
# Epoch 25/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4712 - loss: 1.7770 - val_categorical_accuracy: 0.4458 - val_loss: 1.8020 - learning_rate: 0.0010
# Epoch 26/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4759 - loss: 1.7631 - val_categorical_accuracy: 0.4236 - val_loss: 1.7864 - learning_rate: 0.0010
# Epoch 27/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4916 - loss: 1.7479 - val_categorical_accuracy: 0.4310 - val_loss: 1.7783 - learning_rate: 0.0010
# Epoch 28/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4347 - loss: 1.7623 - val_categorical_accuracy: 0.4507 - val_loss: 1.7219 - learning_rate: 0.0010
# Epoch 29/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4671 - loss: 1.6843 - val_categorical_accuracy: 0.4507 - val_loss: 1.7255 - learning_rate: 0.0010
# Epoch 30/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4592 - loss: 1.7035 - val_categorical_accuracy: 0.4507 - val_loss: 1.6781 - learning_rate: 0.0010
# Epoch 31/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4500 - loss: 1.6791 - val_categorical_accuracy: 0.4286 - val_loss: 1.7001 - learning_rate: 0.0010
# Epoch 32/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4719 - loss: 1.6709 - val_categorical_accuracy: 0.4458 - val_loss: 1.6820 - learning_rate: 0.0010
# Epoch 33/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4514 - loss: 1.6536 - val_categorical_accuracy: 0.4360 - val_loss: 1.7206 - learning_rate: 0.0010
# Epoch 34/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4594 - loss: 1.6754 - val_categorical_accuracy: 0.4680 - val_loss: 1.6432 - learning_rate: 0.0010
# Epoch 35/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4686 - loss: 1.6584 - val_categorical_accuracy: 0.4926 - val_loss: 1.6041 - learning_rate: 0.0010
# Epoch 36/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4603 - loss: 1.6108 - val_categorical_accuracy: 0.4729 - val_loss: 1.6304 - learning_rate: 0.0010
# Epoch 37/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4501 - loss: 1.6555 - val_categorical_accuracy: 0.4458 - val_loss: 1.6304 - learning_rate: 0.0010
# Epoch 38/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4803 - loss: 1.6325 - val_categorical_accuracy: 0.4507 - val_loss: 1.6033 - learning_rate: 0.0010
# Epoch 39/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4696 - loss: 1.6169 - val_categorical_accuracy: 0.4310 - val_loss: 1.6477 - learning_rate: 0.0010
# Epoch 40/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4521 - loss: 1.6222 - val_categorical_accuracy: 0.4680 - val_loss: 1.6168 - learning_rate: 0.0010
# Epoch 41/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4428 - loss: 1.6582 - val_categorical_accuracy: 0.4631 - val_loss: 1.6453 - learning_rate: 0.0010
# Epoch 42/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4790 - loss: 1.5697 - val_categorical_accuracy: 0.4532 - val_loss: 1.5837 - learning_rate: 0.0010
# Epoch 43/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4702 - loss: 1.5717 - val_categorical_accuracy: 0.4039 - val_loss: 1.6430 - learning_rate: 0.0010
# Epoch 44/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4467 - loss: 1.5816 - val_categorical_accuracy: 0.4384 - val_loss: 1.5966 - learning_rate: 0.0010
# Epoch 45/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4690 - loss: 1.5887 - val_categorical_accuracy: 0.4606 - val_loss: 1.5786 - learning_rate: 0.0010
# Epoch 46/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5023 - loss: 1.5251 - val_categorical_accuracy: 0.4557 - val_loss: 1.5756 - learning_rate: 0.0010
# Epoch 47/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4826 - loss: 1.6106 - val_categorical_accuracy: 0.4360 - val_loss: 1.5720 - learning_rate: 0.0010
# Epoch 48/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.4957 - loss: 1.5546 - val_categorical_accuracy: 0.4680 - val_loss: 1.5667 - learning_rate: 0.0010
# Epoch 49/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4791 - loss: 1.5162 - val_categorical_accuracy: 0.4581 - val_loss: 1.5641 - learning_rate: 0.0010
# Epoch 50/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.4809 - loss: 1.5626 - val_categorical_accuracy: 0.4433 - val_loss: 1.5879 - learning_rate: 0.0010
# Epoch 51/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.4585 - loss: 1.5530 - val_categorical_accuracy: 0.4286 - val_loss: 1.5822 - learning_rate: 0.0010
# Epoch 52/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4589 - loss: 1.5297 - val_categorical_accuracy: 0.4729 - val_loss: 1.5455 - learning_rate: 0.0010
# Epoch 53/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4856 - loss: 1.5290 - val_categorical_accuracy: 0.4089 - val_loss: 1.6160 - learning_rate: 0.0010
# Epoch 54/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4520 - loss: 1.5665 - val_categorical_accuracy: 0.4458 - val_loss: 1.5607 - learning_rate: 0.0010
# Epoch 55/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5045 - loss: 1.5184 - val_categorical_accuracy: 0.4335 - val_loss: 1.5690 - learning_rate: 0.0010
# Epoch 56/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - categorical_accuracy: 0.4723 - loss: 1.5241 - val_categorical_accuracy: 0.4483 - val_loss: 1.5552 - learning_rate: 0.0010
# Epoch 57/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.4638 - loss: 1.5605 - val_categorical_accuracy: 0.4606 - val_loss: 1.5299 - learning_rate: 0.0010
# Epoch 58/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5172 - loss: 1.4647 - val_categorical_accuracy: 0.4655 - val_loss: 1.5088 - learning_rate: 0.0010
# Epoch 59/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4898 - loss: 1.4745 - val_categorical_accuracy: 0.4557 - val_loss: 1.5804 - learning_rate: 0.0010
# Epoch 60/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4476 - loss: 1.6137 - val_categorical_accuracy: 0.4458 - val_loss: 1.5265 - learning_rate: 0.0010
# Epoch 61/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4670 - loss: 1.5406 - val_categorical_accuracy: 0.4680 - val_loss: 1.5385 - learning_rate: 0.0010
# Epoch 62/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4529 - loss: 1.5449 - val_categorical_accuracy: 0.4212 - val_loss: 1.5461 - learning_rate: 0.0010
# Epoch 63/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4648 - loss: 1.4979 - val_categorical_accuracy: 0.4360 - val_loss: 1.5375 - learning_rate: 0.0010
# Epoch 64/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.4939 - loss: 1.4625 - val_categorical_accuracy: 0.4655 - val_loss: 1.5019 - learning_rate: 2.0000e-04
# Epoch 65/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5166 - loss: 1.4097 - val_categorical_accuracy: 0.4655 - val_loss: 1.4997 - learning_rate: 2.0000e-04
# Epoch 66/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5388 - loss: 1.3915 - val_categorical_accuracy: 0.4852 - val_loss: 1.4910 - learning_rate: 2.0000e-04
# Epoch 67/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5164 - loss: 1.3669 - val_categorical_accuracy: 0.4901 - val_loss: 1.4791 - learning_rate: 2.0000e-04
# Epoch 68/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5144 - loss: 1.3952 - val_categorical_accuracy: 0.4852 - val_loss: 1.4799 - learning_rate: 2.0000e-04
# Epoch 69/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5375 - loss: 1.3536 - val_categorical_accuracy: 0.4778 - val_loss: 1.4838 - learning_rate: 2.0000e-04
# Epoch 70/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5179 - loss: 1.3516 - val_categorical_accuracy: 0.4532 - val_loss: 1.4737 - learning_rate: 2.0000e-04
# Epoch 71/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5552 - loss: 1.3438 - val_categorical_accuracy: 0.4704 - val_loss: 1.4972 - learning_rate: 2.0000e-04
# Epoch 72/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5295 - loss: 1.3613 - val_categorical_accuracy: 0.4803 - val_loss: 1.4852 - learning_rate: 2.0000e-04
# Epoch 73/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5605 - loss: 1.3592 - val_categorical_accuracy: 0.4754 - val_loss: 1.4677 - learning_rate: 2.0000e-04
# Epoch 74/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5730 - loss: 1.3310 - val_categorical_accuracy: 0.4877 - val_loss: 1.4668 - learning_rate: 2.0000e-04
# Epoch 75/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5591 - loss: 1.3262 - val_categorical_accuracy: 0.4631 - val_loss: 1.4540 - learning_rate: 2.0000e-04
# Epoch 76/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5504 - loss: 1.3233 - val_categorical_accuracy: 0.4852 - val_loss: 1.4568 - learning_rate: 2.0000e-04
# Epoch 77/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5688 - loss: 1.2821 - val_categorical_accuracy: 0.4729 - val_loss: 1.4588 - learning_rate: 2.0000e-04
# Epoch 78/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5620 - loss: 1.3002 - val_categorical_accuracy: 0.4754 - val_loss: 1.4693 - learning_rate: 2.0000e-04
# Epoch 79/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5495 - loss: 1.3366 - val_categorical_accuracy: 0.4581 - val_loss: 1.4600 - learning_rate: 2.0000e-04
# Epoch 80/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5752 - loss: 1.2702 - val_categorical_accuracy: 0.4803 - val_loss: 1.4596 - learning_rate: 2.0000e-04
# Epoch 81/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5789 - loss: 1.2539 - val_categorical_accuracy: 0.4606 - val_loss: 1.4495 - learning_rate: 4.0000e-05
# Epoch 82/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6144 - loss: 1.2171 - val_categorical_accuracy: 0.4704 - val_loss: 1.4474 - learning_rate: 4.0000e-05
# Epoch 83/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5989 - loss: 1.2458 - val_categorical_accuracy: 0.4852 - val_loss: 1.4453 - learning_rate: 4.0000e-05
# Epoch 84/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6277 - loss: 1.2100 - val_categorical_accuracy: 0.4754 - val_loss: 1.4426 - learning_rate: 4.0000e-05
# Epoch 85/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6256 - loss: 1.1900 - val_categorical_accuracy: 0.4729 - val_loss: 1.4484 - learning_rate: 4.0000e-05
# Epoch 86/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6119 - loss: 1.2049 - val_categorical_accuracy: 0.4828 - val_loss: 1.4470 - learning_rate: 4.0000e-05
# Epoch 87/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5767 - loss: 1.2326 - val_categorical_accuracy: 0.4778 - val_loss: 1.4497 - learning_rate: 4.0000e-05
# Epoch 88/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5867 - loss: 1.2219 - val_categorical_accuracy: 0.4754 - val_loss: 1.4518 - learning_rate: 4.0000e-05
# Epoch 89/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5967 - loss: 1.2345 - val_categorical_accuracy: 0.4754 - val_loss: 1.4485 - learning_rate: 4.0000e-05
# Epoch 90/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6131 - loss: 1.2107 - val_categorical_accuracy: 0.4803 - val_loss: 1.4495 - learning_rate: 8.0000e-06
# Epoch 91/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5722 - loss: 1.2642 - val_categorical_accuracy: 0.4852 - val_loss: 1.4503 - learning_rate: 8.0000e-06
# Epoch 92/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.5883 - loss: 1.2238 - val_categorical_accuracy: 0.4852 - val_loss: 1.4514 - learning_rate: 8.0000e-06
# Epoch 93/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6003 - loss: 1.2151 - val_categorical_accuracy: 0.4828 - val_loss: 1.4515 - learning_rate: 8.0000e-06
# Epoch 94/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6280 - loss: 1.1793 - val_categorical_accuracy: 0.4852 - val_loss: 1.4515 - learning_rate: 8.0000e-06
# Epoch 95/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6162 - loss: 1.1741 - val_categorical_accuracy: 0.4852 - val_loss: 1.4515 - learning_rate: 1.6000e-06
# Epoch 96/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5799 - loss: 1.2639 - val_categorical_accuracy: 0.4852 - val_loss: 1.4515 - learning_rate: 1.6000e-06
# Epoch 97/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6028 - loss: 1.1908 - val_categorical_accuracy: 0.4852 - val_loss: 1.4512 - learning_rate: 1.6000e-06
# Epoch 98/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5977 - loss: 1.2011 - val_categorical_accuracy: 0.4828 - val_loss: 1.4514 - learning_rate: 1.6000e-06
# Epoch 99/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6303 - loss: 1.1613 - val_categorical_accuracy: 0.4852 - val_loss: 1.4514 - learning_rate: 1.6000e-06
# Epoch 100/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5958 - loss: 1.2255 - val_categorical_accuracy: 0.4828 - val_loss: 1.4515 - learning_rate: 1.0000e-06
# Epoch 101/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - categorical_accuracy: 0.6046 - loss: 1.2044 - val_categorical_accuracy: 0.4803 - val_loss: 1.4516 - learning_rate: 1.0000e-06
# Epoch 102/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.5862 - loss: 1.2435 - val_categorical_accuracy: 0.4803 - val_loss: 1.4518 - learning_rate: 1.0000e-06
# Epoch 103/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6147 - loss: 1.2127 - val_categorical_accuracy: 0.4828 - val_loss: 1.4521 - learning_rate: 1.0000e-06
# Epoch 104/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - categorical_accuracy: 0.6087 - loss: 1.2170 - val_categorical_accuracy: 0.4828 - val_loss: 1.4523 - learning_rate: 1.0000e-06
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.4628 - loss: 1.4085
# Test Accuracy: 47.53694534301758
# /usr/local/lib/python3.10/dist-packages/keras/src/models/model.py:342: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   warnings.warn(

# %%
#@title Plotting
classes = [
    "Premier",
    "Master",
    "Elite",
    "Veteran",
    "Rival",
    "Challenger",
    "Prospect",
    "Contender",
    "Amateur"
]

# Create a single row with three subplots
fig = plt.figure(figsize=(18, 6))
gs = gridspec.GridSpec(1, 3, width_ratios=[1, 1, 1])

# Plot training loss
ax0 = plt.subplot(gs[0])
ax0.plot(history.history['loss'], label='Training Loss')
ax0.plot(history.history['val_loss'], label='Validation Loss')
ax0.set_title('Loss vs. Iteration')
ax0.set_xlabel('Iteration')
ax0.set_ylabel('Loss')
ax0.legend()

# Plot training accuracy
ax1 = plt.subplot(gs[1])
ax1.plot(history.history['categorical_accuracy'], label='Training Accuracy')
ax1.plot(history.history['val_categorical_accuracy'], label='Validation Accuracy')
ax1.set_title('Accuracy vs. Iteration')
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Accuracy')
ax1.legend()

# Predict the classes on the test set
y_pred = np.argmax(model.predict(X_test_scaled.astype('float16')), axis=1)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display the confusion matrix without color bar
ax2 = plt.subplot(gs[2])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap='viridis', values_format=".4g", ax=ax2, colorbar=False)
ax2.set_title('Confusion Matrix')

# Rotate the bottom labels by 45 degrees
plt.xticks(rotation=45, ha='right')

# Flip the x-axis
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
test_url = "https://ballchasing.com/api/groups/12-2-tourney-groups-mker46age6/"
headers = {'Authorization': '8wjl1G9d8V8Ymfju7hH8K57aKNUiNhYe5oOYOxNr'}
response = requests.get(test_url, headers=headers)
data = json.loads(response.text)
temp_df = pd.json_normalize(data)

# %%
for i in range(len(temp_df)):
  rank_df = pd.DataFrame(pd.json_normalize(temp_df.iloc[i]['players']))
  for j in range(len(rank_df)):
    temp_df = pd.DataFrame(rank_df.iloc[j]).T
    temp_df['rank'] = df.iloc[i]['rank']
    player_df = temp_df if i == 0 and j == 0 else pd.concat([player_df, temp_df])

display(player_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'players'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-200-03a1df35c67d> in <cell line: 1>()
#       1 for i in range(len(temp_df)):
# ----> 2   rank_df = pd.DataFrame(pd.json_normalize(temp_df.iloc[i]['players']))
#       3   for j in range(len(rank_df)):
#       4     temp_df = pd.DataFrame(rank_df.iloc[j]).T
#       5     temp_df['rank'] = df.iloc[i]['rank']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     979
#     980         elif key_is_scalar:
# --> 981             return self._get_value(key)
#     982
#     983         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1087
#    1088         # Similar to Index.get_value, but we do not fall back to positional
# -> 1089         loc = self.index.get_loc(label)
#    1090         return self.index._get_values_for_loc(self, loc, label)
#    1091
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'players'

# %%
temp_player_df = player_df.drop(columns=['platform'], axis=1)
temp_player_df = temp_player_df.drop(columns=['id'], axis=1)
names = temp_player_df['name']
temp_player_df = temp_player_df.drop(columns=['name'], axis=1)
temp_player_df = temp_player_df.drop(columns=['team'], axis=1)

temp_player_df = temp_player_df.drop(columns=['cumulative.games'], axis=1)
# temp_player_df = temp_player_df.filter(like='percent')
# X = np.asarray(temp_player_df)
x = np.asarray(temp_player_df.drop(columns=['rank'], axis=1))

x_scaled = scaler.transform(x)

# %%
predictions = model.predict(x_scaled, batch_size=None, verbose=1)

# print(predictions)

# Set the number of classes
num_classes = 9

# Calculate the number of rows and columns for the grid
num_samples = len(predictions)
num_rows = int(np.ceil(num_samples / 2))
num_cols = 2

# Create a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 16))

# Plot each sample's predictions
for i, pred in enumerate(predictions):
    row_idx = i // num_cols
    col_idx = i % num_cols

    ax = axes[row_idx, col_idx] if num_samples > 1 else axes

    ax.bar(range(num_classes), pred)
    ax.set_xlabel('Rank')
    ax.set_ylabel('Probability')
    ax.set_title(f'{names[i]}')
    ax.set_xticks(range(num_classes))
    ax.set_xticklabels(classes, rotation=45, ha='right')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
